# %% [markdown]
# ## Long-Context Batch Extraction
#
# With the latest gpt-4.1-mini and google gemini-flash

# %%
import os
import time
from collections import defaultdict

import pandas as pd
from litellm import completion
from pydantic import BaseModel

import agent_k.config.experiment_config as config_experiment
import agent_k.config.general as config_general
import agent_k.config.prompts_fast_n_slow as prompts_fast_n_slow
from agent_k.config.logger import logger
from agent_k.config.schemas import create_dynamic_mineral_model
from agent_k.notebooks.agentic_rag_v5 import count_tokens, create_markdown_retriever

# %%
def batch_extract_long_context(
    cdr_record_id: str,
    pydantic_model: BaseModel,
) -> str:
    """
    Extract entities from a PDF file by feeding the entire context to the model.
    """

    # Read with the parsed Markdown file
    with open(
        os.path.join("paper/data/processed/43-101-refined", f"{cdr_record_id}.md"), "r"
    ) as f:
        context = f.read()

    input_tokens = count_tokens(context)
    logger.info(f"[Batch Extraction] Context has {input_tokens} tokens")

    logger.info("[Batch Extraction] Creating structured response")
    input = {
        "model": config_experiment.BATCH_EXTRACTION_MODEL,
        "response_format": pydantic_model,
        "messages": [
            {
                "role": "system",
                "content": prompts_fast_n_slow.PDF_AGENT_SYSTEM_PROMPT_STRUCTURED,
            },
            {
                "role": "user",
                "content": prompts_fast_n_slow.PDF_AGENT_USER_PROMPT_STRUCTURED.format(
                    context=context
                ),
            },
        ],
    }
    if config_experiment.BATCH_EXTRACTION_MODEL not in ["o3-mini", "o4-mini"]:
        input["temperature"] = config_experiment.BATCH_EXTRACTION_TEMPERATURE

    response = completion(**input)

    content = response.choices[0].message.content
    output_tokens = count_tokens(content)
    logger.info(f"[Batch Extraction] Response has {output_tokens} tokens")

    return content, input_tokens, output_tokens

# %% [markdown]
# ## RAG-Based Extraction
#
# Incorporate a retriever to compress the context to be more relevant.

# %%
def batch_extract_rag_based(
    cdr_record_id: str,
    pydantic_model: BaseModel,
) -> str:
    """
    Use a retriever to compress the context to be more relevant before feeding it to the model to extract structured information.
    """

    # Create a Vector Store from markdown file
    markdown_path = os.path.join(
        "paper/data/processed/43-101-refined", f"{cdr_record_id}.md"
    )
    logger.info(f"[Batch Extraction] Creating Vector Store for {cdr_record_id}")
    retriever = create_markdown_retriever(
        markdown_path=markdown_path,
        collection_name=cdr_record_id,
        k=config_experiment.MAX_NUM_RETRIEVED_DOCS,
    )

    # Retrieve context for each fields in the pydantic model
    context = []
    for field_name, field_info in pydantic_model.model_fields.items():
        field_type = field_info.annotation
        default_value = field_info.default if field_info.default else "N/A"
        description = field_info.description
        question = prompts_fast_n_slow.QUESTION_TEMPLATE.format(
            field=field_name,
            dtype=field_type,
            default=default_value,
            description=description,
        )
        context.extend(retriever.invoke(question))
    logger.info(f"[Batch Extraction] Retrieved chunks in context: {len(context)}")

    input_tokens = count_tokens(str(context))
    logger.info(f"[Batch Extraction] Context has {input_tokens} tokens")

    logger.info("[Batch Extraction] Creating structured response")
    input = {
        "model": config_experiment.BATCH_EXTRACTION_MODEL,
        "response_format": pydantic_model,
        "messages": [
            {
                "role": "system",
                "content": prompts_fast_n_slow.PDF_AGENT_SYSTEM_PROMPT_STRUCTURED,
            },
            {
                "role": "user",
                "content": prompts_fast_n_slow.PDF_AGENT_USER_PROMPT_STRUCTURED.format(
                    context=context
                ),
            },
        ],
    }
    if config_experiment.BATCH_EXTRACTION_MODEL not in ["o3-mini", "o4-mini"]:
        input["temperature"] = config_experiment.BATCH_EXTRACTION_TEMPERATURE

    response = completion(**input)

    content = response.choices[0].message.content
    output_tokens = count_tokens(content)
    logger.info(f"[Batch Extraction] Response has {output_tokens} tokens")

    return content, input_tokens, output_tokens

# %%
batch_extract_func_map = {
    config_experiment.BatchExtractionMethod.LONG_CONTEXT: batch_extract_long_context,
    config_experiment.BatchExtractionMethod.RAG_BASED: batch_extract_rag_based,
}


def run_experiment(
    gt_path: str, output_dir: str, setup: config_experiment.BatchExtractionMethod
):
    df_gt = pd.read_csv(gt_path)

    rows = []
    tokens = defaultdict(int)
    start_time = time.time()
    for index, row in df_gt.iterrows():
        # if index > 2:
        #     break
        logger.info(f"Processing row {index + 1} of {len(df_gt)}")
        id = row["id"]
        cdr_record_id = row["cdr_record_id"]
        commodity_observed_name = row["commodity_observed_name"]

        try:
            pydantic_model = create_dynamic_mineral_model(commodity_observed_name)
            output, input_tokens, output_tokens = batch_extract_func_map[setup](
                cdr_record_id, pydantic_model
            )
            mineral_site_metadata = pydantic_model.model_validate_json(output)
            mineral_site_metadata = {
                "id": id,
                "cdr_record_id": cdr_record_id,
                **mineral_site_metadata.model_dump(),
            }
            rows.append(mineral_site_metadata)

            # Track tokens
            tokens["input_tokens"] += input_tokens
            tokens["output_tokens"] += output_tokens
        except Exception as e:
            logger.exception(
                f"Error processing row {index + 1} of {len(df_gt)} (Skipping): {e}"
            )

    end_time = time.time()

    df_pred = pd.DataFrame(rows)
    logger.info(
        f"Successfully extracted {len(df_pred)} reports. Write to experiment results directory."
    )
    # Generate timestamp once for both files
    os.makedirs(output_dir, exist_ok=True)

    # Save results to CSV
    timestamp = config_general.get_curr_ts()
    df_pred.to_csv(f"{output_dir}/{timestamp}_batch_extraction.csv", index=False)

    # Log experiment results
    logger.info(f"Experiment setup: {setup}")
    logger.info(f"Total time taken: {end_time - start_time} seconds")
    logger.info(f"Total input tokens: {tokens['input_tokens']}")
    logger.info(f"Total output tokens: {tokens['output_tokens']}")
    logger.info(
        f"Average input tokens per row: {tokens['input_tokens'] / len(df_gt):.2f}"
    )
    logger.info(
        f"Average output tokens per row: {tokens['output_tokens'] / len(df_gt):.2f}"
    )

    # Save experiment metadata to yaml file
    import yaml

    experiment_metadata = {
        "timestamp": timestamp,
        "setup": setup,
        "model": config_experiment.BATCH_EXTRACTION_MODEL,
        "temperature": config_experiment.BATCH_EXTRACTION_TEMPERATURE,
        "max_num_results": "N/A (long context)",
        "total_time_seconds": end_time - start_time,
        "total_input_tokens": tokens["input_tokens"],
        "total_output_tokens": tokens["output_tokens"],
        "average_input_tokens_per_row": tokens["input_tokens"] / len(df_gt),
        "average_output_tokens_per_row": tokens["output_tokens"] / len(df_gt),
        "num_rows_processed": len(df_pred),
        "total_rows": len(df_gt),
    }
    with open(f"{output_dir}/{timestamp}_experiment_metadata.yaml", "w") as f:
        yaml.dump(experiment_metadata, f)


if __name__ == "__main__":
    # ----------------------------------------------------------------------------------
    # Note: Hyperparameters (configured manually in config/experiment_config.py)
    # ----------------------------------------------------------------------------------
    # Models: ["gpt-4.1-mini"]
    # Setups: ["long_context", "rag_based"]
    # Temperature: [0.1]
    # Max retrieved results: [5] --> only applicable to rag_based
    output_dir = "paper/data/experiments/250628_rag_batch_extraction"
    gt_path = "paper/data/processed/ground_truth/inferlink_ground_truth.csv"

    run_experiment(
        gt_path=gt_path,
        output_dir=output_dir,
        setup=config_experiment.BatchExtractionMethod.RAG_BASED,
    )
# Out:
# 2025-06-28 20:30:36.800 | INFO     | __main__:run_experiment:16 - Processing row 1 of 50
# 2025-06-28 20:30:36.801 | INFO     | __main__:batch_extract_rag_based:11 - [Batch Extraction] Creating Vector Store for 0200a1c6d2cfafeb485d815d95966961d4c119e8662b8babec74e05b59ba4759d2
# 2025-06-28 20:30:36.842 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:102 - Number of tokens: 49301
# 2025-06-28 20:30:36.843 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:103 - Number of splits: 52
# 2025-06-28 20:30:36.844 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:104 - Average tokens per split: 948
# 2025-06-28 20:30:36.995 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:117 - Hashed collection name: rag-chroma_shard_4
# 2025-06-28 20:30:39.671 | INFO     | __main__:batch_extract_rag_based:31 - [Batch Extraction] Retrieved chunks in context: 20
# 2025-06-28 20:30:39.682 | INFO     | __main__:batch_extract_rag_based:34 - [Batch Extraction] Context has 17513 tokens
# 2025-06-28 20:30:39.683 | INFO     | __main__:batch_extract_rag_based:36 - [Batch Extraction] Creating structured response
# 2025-06-28 20:30:40.872 | INFO     | __main__:batch_extract_rag_based:60 - [Batch Extraction] Response has 48 tokens
# 2025-06-28 20:30:40.873 | INFO     | __main__:run_experiment:16 - Processing row 2 of 50
# 2025-06-28 20:30:40.874 | INFO     | __main__:batch_extract_rag_based:11 - [Batch Extraction] Creating Vector Store for 0204fc707f5b1944308624520cd422c4f1cb478046f66487b06a27e8fbd8f0fd86
# 2025-06-28 20:30:40.915 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:102 - Number of tokens: 55017
# 2025-06-28 20:30:40.916 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:103 - Number of splits: 83
# 2025-06-28 20:30:40.916 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:104 - Average tokens per split: 663
# 2025-06-28 20:30:40.918 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:117 - Hashed collection name: rag-chroma_shard_5
# 2025-06-28 20:30:43.645 | INFO     | __main__:batch_extract_rag_based:31 - [Batch Extraction] Retrieved chunks in context: 20
# 2025-06-28 20:30:43.661 | INFO     | __main__:batch_extract_rag_based:34 - [Batch Extraction] Context has 28895 tokens
# 2025-06-28 20:30:43.662 | INFO     | __main__:batch_extract_rag_based:36 - [Batch Extraction] Creating structured response
# 2025-06-28 20:30:45.658 | INFO     | __main__:batch_extract_rag_based:60 - [Batch Extraction] Response has 49 tokens
# 2025-06-28 20:30:45.659 | INFO     | __main__:run_experiment:16 - Processing row 3 of 50
# 2025-06-28 20:30:45.660 | INFO     | __main__:batch_extract_rag_based:11 - [Batch Extraction] Creating Vector Store for 020548e1aca4c1ca222149e11a79f15bd7594c02eb12163a1793a782fc2ec3619c
# 2025-06-28 20:30:45.718 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:102 - Number of tokens: 76456
# 2025-06-28 20:30:45.719 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:103 - Number of splits: 147
# 2025-06-28 20:30:45.719 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:104 - Average tokens per split: 520
# 2025-06-28 20:30:45.721 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:117 - Hashed collection name: rag-chroma_shard_9
# 2025-06-28 20:30:49.462 | INFO     | __main__:batch_extract_rag_based:31 - [Batch Extraction] Retrieved chunks in context: 20
# 2025-06-28 20:30:49.500 | INFO     | __main__:batch_extract_rag_based:34 - [Batch Extraction] Context has 37428 tokens
# 2025-06-28 20:30:49.501 | INFO     | __main__:batch_extract_rag_based:36 - [Batch Extraction] Creating structured response
# 2025-06-28 20:30:51.616 | INFO     | __main__:batch_extract_rag_based:60 - [Batch Extraction] Response has 48 tokens
# 2025-06-28 20:30:51.617 | INFO     | __main__:run_experiment:16 - Processing row 4 of 50
# 2025-06-28 20:30:51.618 | INFO     | __main__:batch_extract_rag_based:11 - [Batch Extraction] Creating Vector Store for 02163e7674b5c838a0efd7d2e80116e36ba01cbdb1d892921ec50e12dc041de809
# 2025-06-28 20:30:51.683 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:102 - Number of tokens: 104507
# 2025-06-28 20:30:51.684 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:103 - Number of splits: 99
# 2025-06-28 20:30:51.684 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:104 - Average tokens per split: 1056
# 2025-06-28 20:30:51.686 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:117 - Hashed collection name: rag-chroma_shard_8
# 2025-06-28 20:30:54.199 | INFO     | __main__:batch_extract_rag_based:31 - [Batch Extraction] Retrieved chunks in context: 20
# 2025-06-28 20:30:54.214 | INFO     | __main__:batch_extract_rag_based:34 - [Batch Extraction] Context has 29347 tokens
# 2025-06-28 20:30:54.215 | INFO     | __main__:batch_extract_rag_based:36 - [Batch Extraction] Creating structured response
# 2025-06-28 20:30:55.605 | INFO     | __main__:batch_extract_rag_based:60 - [Batch Extraction] Response has 48 tokens
# 2025-06-28 20:30:55.606 | INFO     | __main__:run_experiment:16 - Processing row 5 of 50
# 2025-06-28 20:30:55.607 | INFO     | __main__:batch_extract_rag_based:11 - [Batch Extraction] Creating Vector Store for 02195e2ef16f106876aff4c08b7a53a04edc8630e7ee0a23f16b61a8b066892e8e
# 2025-06-28 20:30:55.667 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:102 - Number of tokens:
agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:150 - Error creating retriever: Error code: 400 - {'error': {'message': 'Requested 359623 tokens, max 300000 tokens per request', 'type': 'max_tokens_per_request', 'param': None, 'code': 'max_tokens_per_request'}}
# 2025-06-28 20:33:06.073 | ERROR    | __main__:run_experiment:40 - Error processing row 26 of 50 (Skipping): Error code: 400 - {'error': {'message': 'Requested 359623 tokens, max 300000 tokens per request', 'type': 'max_tokens_per_request', 'param': None, 'code': 'max_tokens_per_request'}}
# Traceback (most recent call last):
#
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/yixin0829/minmod/agent-k/.venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#     │   └ <bound method Application.launch_instance of <class 'ipykernel.kernelapp.IPKernelApp'>>
#     └ <module 'ipykernel.kernelapp' from '/home/yixin0829/minmod/agent-k/.venv/lib/python3.12/site-packages/ipykernel/kernelapp.py'>
#   File "/home/yixin0829/minmod/agent-k/.venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#     │   └ <function IPKernelApp.start at 0x774bb1e63420>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x774bb3c374a0>
#   File "/home/yixin0829/minmod/agent-k/.venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#     │    │       └ <function BaseAsyncIOLoop.start at 0x774bb1ca8220>
#     │    └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x774bb1c9b230>
#     └ <ipykernel.kernelapp.IPKernelApp object at 0x774bb3c374a0>
#   File "/home/yixin0829/minmod/agent-k/.venv/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#     │    │            └ <function BaseEventLoop.run_forever at 0x774bb325aca0>
#     │    └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#     └ <tornado.platform.asyncio.AsyncIOMainLoop object at 0x774bb1c9b230>
#   File "/home/yixin0829/.local/share/uv/python/cpython-3.12.5-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#     │    └ <function BaseEventLoop._run_once at 0x774bb325cae0>
#     └ <_UnixSelectorEventLoop running=True closed=False debug=False>
#   File "/home/yixin0829/.local/share/uv/python/cpython-3.12.5-linux-x86_64-gnu/lib/python3.12/asyncio/base_events.py", line 1986, in _run_once
#     handle._run()
#     │      └ <function Handle._run at 0x774bb33fc400>
#     └ <Handle Task.task_wakeup(<Future finis...7B)>, ...],))>)>
#   File "/home/yixin0829/.local/share/uv/python/cpython-3.12.5-linux-x86_64-gnu/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#     │    │            │    │           │    └ <member '_args' of 'Handle' objects>
#     │    │            │    │           └ <Handle Task.task_wakeup(<Future finis...7B)>, ...],))>)>
#     │    │            │    └ <member '_callback' of 'Handle' objects>
#     │    │            └ <Handle Task.task_wakeup(<Future finis...7B)>, ...],))>)>
#     │    └ <member '_context' of 'Handle' objects>
#     └ <Handle Task.task_wakeup(<Future finis...7B)>, ...],))>)>
#   File "/home/yixin0829/minmod/agent-k/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#           │    └ <function Kernel.process_one at 0x774bb1e12f20>
#           └ <ipykernel.ipkernel.IPythonKernel object at 0x774bb1e57530>
#   File "/home/yixin0829/minmod/agent-k/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#           │         └ ([<zmq.Frame(b'3afa9d5f-7c1'...36B)>, <zmq.Frame(b'<IDS|MSG>')>, <zmq.Frame(b'72b57c344577'...64B)>, <zmq.Frame(b'{"date":"20...
#           └ <bound method Kernel.dispatch_shell of <ipykernel.ipkernel.IPythonKernel object at 0x774bb1e57530>>
#   File "/home/yixin0829/minmod/agent-k/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#           └ <coroutine object IPythonKernel.execute_request at 0x774ba866bb40>
#   File "/home/yixin0829/minmod/agent-k/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#                                   │       │      └ {'header': {'date': datetime.datetime(2025, 6, 29, 0, 30, 36, 786000, tzinfo=tzutc()), 'msg_id': '7376525b-8d25-42f9-9d00-a0a...
#                                   │       └ [b'3afa9d5f-7c1e-464b-9801-240ecc788ed6']
#                                   └ <zmq.eventloop.zmqstream.ZMQStream object at 0x774bb1c9aff0>
#   File "/home/yixin0829/minmod/agent-k/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#                           └ <coroutine object IPythonKernel.do_execute at 0x774bb1f477c0>
#   File "/home/yixin0829/minmod/agent-k/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#           │     └ <function ZMQInteractiveShell.run_cell at 0x774bb1e42fc0>
#           └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x774bb00f0800>
#   File "/home/yixin0829/minmod/agent-k/.venv/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#                              │       └ {'store_history': True, 'silent': False, 'cell_id': 'vscode-notebook-cell://wsl%2Bubuntu/home/yixin0829/minmod/agent-k/paper/...
#                              └ ('batch_extract_func_map = {\n    config_experiment.BatchExtractionMethod.LONG_CONTEXT: batch_extract_long_context,\n    conf...
#   File "/home/yixin0829/minmod/agent-k/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3098, in run_cell
#     result = self._run_cell(
#              │    └ <function InteractiveShell._run_cell at 0x774bb269a020>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x774bb00f0800>
#   File "/home/yixin0829/minmod/agent-k/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3153, in _run_cell
#     result = runner(coro)
#              │      └ <coroutine object InteractiveShell.run_cell_async at 0x774bb023a8e0>
#              └ <function _pseudo_sync_runner at 0x774bb2689080>
#   File "/home/yixin0829/minmod/agent-k/.venv/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#     │    └ <method 'send' of 'coroutine' objects>
#     └ <coroutine object InteractiveShell.run_cell_async at 0x774bb023a8e0>
#   File "/home/yixin0829/minmod/agent-k/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3365, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                        │    │             │        │     └ '/tmp/ipykernel_25188/2777673115.py'
#                        │    │             │        └ [<ast.Assign object at 0x774b583e1710>, <ast.FunctionDef object at 0x774b5b66a890>, <ast.If object at 0x774b58200190>]
#                        │    │             └ <ast.Module object at 0x774b583e1690>
#                        │    └ <function InteractiveShell.run_ast_nodes at 0x774bb269a3e0>
#                        └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x774bb00f0800>
#   File "/home/yixin0829/minmod/agent-k/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3610, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#              │    │        │     │              └ False
#              │    │        │     └ <ExecutionResult object at 774ba86dd4f0, execution_count=4 error_before_exec=None error_in_exec=None info=<ExecutionInfo obje...
#              │    │        └ <code object <module> at 0x774b5b653660, file "/tmp/ipykernel_25188/2777673115.py", line 1>
#              │    └ <function InteractiveShell.run_code at 0x774bb269a480>
#              └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x774bb00f0800>
#   File "/home/yixin0829/minmod/agent-k/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3670, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#          │         │    │               │    └ <property object at 0x774bb2686390>
#          │         │    │               └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x774bb00f0800>
#          │         │    └ <property object at 0x774bb2686430>
#          │         └ <ipykernel.zmqshell.ZMQInteractiveShell object at 0x774bb00f0800>
#          └ <code object <module> at 0x774b5b653660, file "/tmp/ipykernel_25188/2777673115.py", line 1>
#
#   File "/tmp/ipykernel_25188/2777673115.py", line 98, in <module>
#     run_experiment(
#     └ <function run_experiment at 0x774b583ae3e0>
#
# > File "/tmp/ipykernel_25188/2777673115.py", line 23, in run_experiment
#     output, input_tokens, output_tokens = batch_extract_func_map[setup](
#     │       │                             │                      └ <BatchExtractionMethod.RAG_BASED: 'rag_based'>
#     │       │                             └ {<BatchExtractionMethod.LONG_CONTEXT: 'long_context'>: <function batch_extract_long_context at 0x774b583aeb60>, <BatchExtract...
#     │       └ 8248
#     └ '{"total_mineral_resource_tonnage":2926880,"total_mineral_reserve_tonnage":0,"total_mineral_resource_contained_metal":13494.5...
#
#   File "/tmp/ipykernel_25188/565730718.py", line 12, in batch_extract_rag_based
#     retriever = create_markdown_retriever(
#                 └ <function create_markdown_retriever at 0x774b58340360>
#
#   File "/home/yixin0829/minmod/agent-k/agent_k/notebooks/agentic_rag_v5.py", line 145, in create_markdown_retriever
#     vectorstore.add_documents(documents=batch)
#     │           │                       └ [Document(metadata={'Header 1': 'Appendix 6: Diamond drill hole logs.# Appendix: Diamond drill hole logs.', 'Header 2': 'Lege...
#     │           └ <function VectorStore.add_documents at 0x774b58a42020>
#     └ <langchain_chroma.vectorstores.Chroma object at 0x774b57f81490>
#
#   File "/home/yixin0829/minmod/agent-k/.venv/lib/python3.12/site-packages/langchain_core/vectorstores/base.py", line 288, in add_documents
#     return self.add_texts(texts, metadatas, **kwargs)
#            │    │         │      │            └ {}
#            │    │         │      └ [{'Header 1': 'Appendix 6: Diamond drill hole logs.# Appendix: Diamond drill hole logs.', 'Header 2': 'Legend:'}]
#            │    │         └ ["7. Overburden - Till, Sand, Silt\n8. 'Trench': Collapse Breccia, Ancient Till\n9. Corroll's Corner Formation:  \nEvaporites...
#            │    └ <function Chroma.add_texts at 0x774b58a43d80>
#            └ <langchain_chroma.vectorstores.Chroma object at 0x774b57f81490>
#   File "/home/yixin0829/minmod/agent-k/.venv/lib/python3.12/site-packages/langchain_chroma/vectorstores.py", line 527, in add_texts
#     embeddings = self._embedding_function.embed_documents(texts)
#                  │    │                   │               └ ["7. Overburden - Till, Sand, Silt\n8. 'Trench': Collapse Breccia, Ancient Till\n9. Corroll's Corner Formation:  \nEvaporites...
#                  │    │                   └ <function OpenAIEmbeddings.embed_documents at 0x774b586a1760>
#                  │    └ OpenAIEmbeddings(client=<openai.resources.embeddings.Embeddings object at 0x774b57f5d7c0>, async_client=<openai.resources.emb...
#                  └ <langchain_chroma.vectorstores.Chroma object at 0x774b57f81490>
#   File "/home/yixin0829/minmod/agent-k/.venv/lib/python3.12/site-packages/langchain_openai/embeddings/base.py", line 576, in embed_documents
#     return self._get_len_safe_embeddings(texts, engine=engine)
# ...
# 2025-06-28 20:34:07.283 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:104 - Average tokens per split: 467
# 2025-06-28 20:34:07.285 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:117 - Hashed collection name: rag-chroma_shard_8
# 2025-06-28 20:34:07.290 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:122 - Deleted existing collection: rag-chroma_shard_8
# 2025-06-28 20:34:09.523 | INFO     | __main__:batch_extract_rag_based:31 - [Batch Extraction] Retrieved chunks in context: 20
# 2025-06-28 20:34:09.559 | INFO     | __main__:batch_extract_rag_based:34 - [Batch Extraction] Context has 40822 tokens
# 2025-06-28 20:34:09.560 | INFO     | __main__:batch_extract_rag_based:36 - [Batch Extraction] Creating structured response
# 2025-06-28 20:34:11.400 | INFO     | __main__:batch_extract_rag_based:60 - [Batch Extraction] Response has 48 tokens
# 2025-06-28 20:34:11.401 | INFO     | __main__:run_experiment:16 - Processing row 41 of 50
# 2025-06-28 20:34:11.402 | INFO     | __main__:batch_extract_rag_based:11 - [Batch Extraction] Creating Vector Store for 02b20820f4c67344312d82445536f374e15a2a712e4479875ae3c8901572a14b33
# 2025-06-28 20:34:11.501 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:102 - Number of tokens: 166656
# 2025-06-28 20:34:11.502 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:103 - Number of splits: 271
# 2025-06-28 20:34:11.502 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:104 - Average tokens per split: 615
# 2025-06-28 20:34:11.505 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:117 - Hashed collection name: rag-chroma_shard_4
# 2025-06-28 20:34:11.510 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:122 - Deleted existing collection: rag-chroma_shard_4
# 2025-06-28 20:34:15.807 | INFO     | __main__:batch_extract_rag_based:31 - [Batch Extraction] Retrieved chunks in context: 20
# 2025-06-28 20:34:15.816 | INFO     | __main__:batch_extract_rag_based:34 - [Batch Extraction] Context has 19501 tokens
# 2025-06-28 20:34:15.817 | INFO     | __main__:batch_extract_rag_based:36 - [Batch Extraction] Creating structured response
# 2025-06-28 20:34:17.003 | INFO     | __main__:batch_extract_rag_based:60 - [Batch Extraction] Response has 45 tokens
# 2025-06-28 20:34:17.004 | INFO     | __main__:run_experiment:16 - Processing row 42 of 50
# 2025-06-28 20:34:17.006 | INFO     | __main__:batch_extract_rag_based:11 - [Batch Extraction] Creating Vector Store for 02b9ba7f8441a85820598cf896e53ed2d92d08c594e3dec861824d50ea45e3299e
# 2025-06-28 20:34:17.111 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:102 - Number of tokens: 145269
# 2025-06-28 20:34:17.112 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:103 - Number of splits:
| INFO     | __main__:batch_extract_rag_based:60 - [Batch Extraction] Response has 49 tokens
# 2025-06-28 20:34:42.546 | INFO     | __main__:run_experiment:16 - Processing row 48 of 50
# 2025-06-28 20:34:42.547 | INFO     | __main__:batch_extract_rag_based:11 - [Batch Extraction] Creating Vector Store for 02f011a7f2a8dd69ce2abb6ea2b90f84f3fa4d6d443d969bbf843740e2f4b18ad1
# 2025-06-28 20:34:42.604 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:102 - Number of tokens: 80421
# 2025-06-28 20:34:42.604 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:103 - Number of splits: 150
# 2025-06-28 20:34:42.605 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:104 - Average tokens per split: 536
# 2025-06-28 20:34:42.607 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:117 - Hashed collection name: rag-chroma_shard_1
# 2025-06-28 20:34:42.610 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:122 - Deleted existing collection: rag-chroma_shard_1
# 2025-06-28 20:34:45.602 | INFO     | __main__:batch_extract_rag_based:31 - [Batch Extraction] Retrieved chunks in context: 20
# 2025-06-28 20:34:45.629 | INFO     | __main__:batch_extract_rag_based:34 - [Batch Extraction] Context has 25605 tokens
# 2025-06-28 20:34:45.630 | INFO     | __main__:batch_extract_rag_based:36 - [Batch Extraction] Creating structured response
# 2025-06-28 20:34:47.325 | INFO     | __main__:batch_extract_rag_based:60 - [Batch Extraction] Response has 51 tokens
# 2025-06-28 20:34:47.326 | INFO     | __main__:run_experiment:16 - Processing row 49 of 50
# 2025-06-28 20:34:47.328 | INFO     | __main__:batch_extract_rag_based:11 - [Batch Extraction] Creating Vector Store for 02fbe6e649215a04386141250f3d6657f3887371021baf75e756ee8248ce018f0c
# 2025-06-28 20:34:47.355 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:102 - Number of tokens: 45517
# 2025-06-28 20:34:47.356 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:103 - Number of splits: 106
# 2025-06-28 20:34:47.357 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:104 - Average tokens per split: 429
# 2025-06-28 20:34:47.359 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:117 - Hashed collection name: rag-chroma_shard_0
# 2025-06-28 20:34:50.045 | INFO     | __main__:batch_extract_rag_based:31 - [Batch Extraction] Retrieved chunks in context: 20
# 2025-06-28 20:34:50.058 | INFO     | __main__:batch_extract_rag_based:34 - [Batch Extraction] Context has 21327 tokens
# 2025-06-28 20:34:50.059 | INFO     | __main__:batch_extract_rag_based:36 - [Batch Extraction] Creating structured response
# 2025-06-28 20:34:51.723 | INFO     | __main__:batch_extract_rag_based:60 - [Batch Extraction] Response has 47 tokens
# 2025-06-28 20:34:51.724 | INFO     | __main__:run_experiment:16 - Processing row 50 of 50
# 2025-06-28 20:34:51.725 | INFO     | __main__:batch_extract_rag_based:11 - [Batch Extraction] Creating Vector Store for 02fd98e067010f8d853d2c018cb002be462ac7fcd895af4125beb89f42b659f89d
# 2025-06-28 20:34:51.804 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:102 - Number of tokens: 92397
# 2025-06-28 20:34:51.805 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:103 - Number of splits: 175
# 2025-06-28 20:34:51.806 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:104 - Average tokens per split: 528
# 2025-06-28 20:34:51.808 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:117 - Hashed collection name: rag-chroma_shard_7
# 2025-06-28 20:34:51.816 | INFO     | agent_k.notebooks.agentic_rag_v5:create_markdown_retriever:122 - Deleted existing collection: rag-chroma_shard_7
# 2025-06-28 20:34:54.839 | INFO     | __main__:batch_extract_rag_based:31 - [Batch Extraction] Retrieved chunks in context: 20
# 2025-06-28 20:34:54.856 | INFO     | __main__:batch_extract_rag_based:34 - [Batch Extraction] Context has 34530 tokens
# 2025-06-28 20:34:54.857 | INFO     | __main__:batch_extract_rag_based:36 - [Batch Extraction] Creating structured response
# 2025-06-28 20:34:56.549 | INFO     | __main__:batch_extract_rag_based:60 - [Batch Extraction] Response has 49 tokens
# 2025-06-28 20:34:56.551 | INFO     | __main__:run_experiment:47 - Successfully extracted 49 reports. Write to experiment results directory.
# 2025-06-28 20:34:56.554 | INFO     | __main__:run_experiment:58 - Experiment setup: BatchExtractionMethod.RAG_BASED
# 2025-06-28 20:34:56.554 | INFO     | __main__:run_experiment:59 - Total time taken: 259.7506160736084 seconds
# 2025-06-28 20:34:56.555 | INFO     | __main__:run_experiment:60 - Total input tokens: 1376164
# 2025-06-28 20:34:56.556 | INFO     | __main__:run_experiment:61 - Total output tokens: 2339
# 2025-06-28 20:34:56.556 | INFO     | __main__:run_experiment:62 - Average input tokens per row: 27523.28
# 2025-06-28 20:34:56.557 | INFO     | __main__:run_experiment:65 - Average output tokens per row: 46.78
